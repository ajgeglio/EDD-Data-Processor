# %%
import pandas as pd

# %%
file = pd.read_excel("..\\Sanitas2Q26.xlsx")
# remove the time from SAMPLE_DATE so it is just the date
file["SAMPLE_DATE"] = file["SAMPLE_DATE"].dt.date
file
# Out:
#      SYS_LOC_CODE SAMPLE_DATE            CHEMICAL_NAME  \
# 0    JCW-MW-18001  2026-05-07  Alkalinity, bicarbonate
# 1    JCW-MW-18001  2026-05-07    Alkalinity, carbonate
# 2    JCW-MW-18001  2026-05-07        Alkalinity, total
# 3    JCW-MW-18001  2026-05-07                 Antimony
# 4    JCW-MW-18001  2026-05-07                  Arsenic
# ..            ...         ...                      ...
# 529     OW-57ROUT  2026-05-05                 Thallium
# 530     OW-57ROUT  2026-05-05   Total Dissolved Solids
# 531     OW-57ROUT  2026-05-05         Turbidity, Field
# 532     OW-57ROUT  2026-05-05                 Vanadium
# 533     OW-57ROUT  2026-05-05                     Zinc
#
#      REPORTING_DETECTION_LIMIT DETECT_FLAG  RESULT_NUMERIC RESULT_UNIT
# 0                      10000.0         NaN       718000.00        ug/L
# 1                      10000.0          ND             NaN         NaN
# 2                      10000.0         NaN       718000.00        ug/L
# ...

# %%
# save this file as ascii text file with tab delimiter
file.to_csv("..\\Sanitas2Q26.txt", sep="\t", index=False)
